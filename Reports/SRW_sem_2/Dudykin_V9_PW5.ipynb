# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.manifold import TSNE




data = pd.read_csv('California_Fire_Incidents.csv')

data.shape
#Tаблица содержит 1636 строк (объектов) и 40 столбцов (признаков).
# Out:
# (1636, 40)

# %%
data.head()
# Out:
#    AcresBurned  Active                                          AdminUnit  \
# 0     257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1      30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2      27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3      27440.0   False                              Tahoe National Forest
# 4      24251.0   False                       Ventura County Fire/CAL FIRE
#
#    AirTankers  ArchiveYear  CalFireIncident  \
# 0         NaN         2013             True
# 1         NaN         2013             True
# 2         NaN         2013             True
# 3         NaN         2013            False
# 4         NaN         2013             True
#
#                             CanonicalUrl  \
# 0         /incidents/2013/8/17/rim-fire/
# 1  /incidents/2013/5/30/powerhouse-fire/
# 2    /incidents/2013/7/15/mountain-fire/
# 3    /incidents/2013/8/10/american-fire/
# 4      /incidents/2013/5/2/springs-fire/
#
#                                   ConditionStatement ControlStatement  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4  Acreage has been reduced based upon more accur...              NaN
#
#       Counties  ...                                     SearchKeywords  \
# 0     Tuolumne  ...  Rim Fire, Stanislaus National Forest, Yosemite...
# 1  Los Angeles  ...  Powerhouse Fire, May 2013, June 2013, Angeles ...
# 2    Riverside  ...  Mountain Fire, July 2013, Highway 243, Highway...
# 3       Placer  ...  American Fire, August 2013, Deadwood Ridge, Fo...
# 4      Ventura  ...  Springs Fire, May 2013, Highway 101, Camarillo...
#
#                 Started     Status  StructuresDamaged StructuresDestroyed  \
# 0  2013-08-17T15:25:00Z  Finalized                NaN                 NaN
# 1  2013-05-30T15:28:00Z  Finalized                NaN                 NaN
# 2  2013-07-15T13:43:00Z  Finalized                NaN                 NaN
# 3  2013-08-10T16:30:00Z  Finalized                NaN                 NaN
# 4  2013-05-02T07:01:00Z  Finalized                6.0                10.0
#
#    StructuresEvacuated  StructuresThreatened  \
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
#
#                                UniqueId               Updated  WaterTenders
# 0  5fb18d4d-213f-4d83-a179-daaf11939e78  2013-09-06T18:30:00Z           NaN
# 1  bf37805e-1cc2-4208-9972-753e47874c87  2013-06-08T18:30:00Z           NaN
# 2  a3149fec-4d48-427c-8b2c-59e8b79d59db  2013-07-30T18:00:00Z           NaN
# 3  8213f5c7-34fa-403b-a4bc-da2ace6e6625  2013-08-30T08:00:00Z           NaN
# 4  46731fb8-3350-4920-bdf7-910ac0eb715c  2013-05-11T06:30:00Z          11.0
#
# [5 rows x 40 columns]

# %%
#Описание признаков:
#    AcresBurned: Акров земли, пострадавших от лесных пожаров
#    Active: Является ли пожар активным или локализованным?
#    AdminUnit: Административное подразделение
#    AirTankers: Выделенные ресурсы
#    ArchiveYear: Год, когда данные были заархивированы
#    CalFireIncident: Рассматривается ли этот инцидент как инцидент с пожаром?
#    Counties: Название округа
#    CountyIds: Идентификационный номер округа
#    CrewsInvolved: Вовлеченные экипажи
#    Dozers: Выделенные бульдозеры
#    Engines: Выделенные машины
#    Extinguished: Дата погашения
#    Fatalities: Количество погибших
#    Helicopters: Выделенные вертолеты
#    Injuries: Количество раненых среди персонала
#    Latitude: Широта инцидента с лесным пожаром
#    Location: Описание местоположения
#    Longitude: Долгота инцидента с лесным пожаром
#    MajorIncident: Считается ли это серьезным инцидентом или нет?
#    Name: Название лесного пожара
#    PercentContained: Какой процент пожара локализован?
#    PersonnelInvolved: Вовлеченный персонал
#    Started: Дата начала пожара
#    StructuresDamaged: Количество поврежденных конструкций
#    StructuresDestroyed: Количество разрушенных сооружений
#    StructuresThreatened: Количество сооружений, находящихся под угрозой
#    WaterTenders: Выделенные объем воды
#        
#Из них категориальные:
#    AdminUnit
#    Counties
#    CountyIds
#    Name

# %%
#Counties и CountyIds обозаначают обно и тоже, поэтому рассматриваю только один из них

unique = [[], [], []]
k = 0

for i in ['AdminUnit', 'Counties', 'Name']:
    for j in range(0, 1636):
        if not(data[i][j] in unique[k]):
            unique[k].append(data[i][j])
    
    k=k+1

for i in unique:
    print(len(i))
# Out:
# 494
# 59
# 1193

# %%
#Столбецом с макимальным количеством уникальных значений категориального признака является Name
#с количеством уникальных значений 1193
data = data.drop(['AdminUnit', 'Counties', 'CountyIds', 'Name'], axis = 1)

# %%
#Есть бинарные признаки, к ним относятся:
#    Active
#    CalFireIncident
#    Featured
#    Final
#    MajorIncident
#    Public
#    Status

bin_cols = ['Active', 'CalFireIncident', 'Featured', 'Final', 'MajorIncident', 'Public', 'Status']
num_cols = ['AcresBurned', 'AirTankers', 'CrewsInvolved', 'Dozers', 'Engines', 'Fatalities', 'Helicopters', 'Injuries', 'PersonnelInvolved', 'StructuresDamaged', 'StructuresDestroyed', 'WaterTenders']

data['Active'] = np.where(data['Active'] == 'False', 0, 1)
data['CalFireIncident'] = np.where(data['CalFireIncident'] == 'False', 0, 1)
data['Featured'] = np.where(data['Featured'] == 'False', 0, 1)
data['Final'] = np.where(data['Final'] == 'False', 0, 1)
data['MajorIncident'] = np.where(data['MajorIncident'] == 'False', 0, 1)
data['Public'] = np.where(data['Public'] == 'False', 0, 1)
data['Status'] = np.where(data['Status'] == 'Inactive', 0, 1)
# Out:
# D:\Programs\Anaconda\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
col = []
j = 0
for i in data.isna().any():
    if i:
        col.append(data.columns[j])
    j+=1

print(col, " : ", len(col))
# Out:
# ['AcresBurned', 'AirTankers', 'ConditionStatement', 'ControlStatement', 'CrewsInvolved', 'Dozers', 'Engines', 'Extinguished', 'Fatalities', 'FuelType', 'Helicopters', 'Injuries', 'PercentContained', 'PersonnelInvolved', 'SearchDescription', 'SearchKeywords', 'StructuresDamaged', 'StructuresDestroyed', 'StructuresEvacuated', 'StructuresThreatened', 'WaterTenders']  :  21

# %%
#Пропуски присутствуют в 21 столбце
#Эти столбцы видны выше

# %%
data_temp = data

count_na = []

for i in col:
    data_temp[i].dropna()
    count_na.append(1636 - data_temp[i].count())
    
#for i, j in zip(col, count_na):
#    if j > 1300:
#        data = data.drop([i], axis = 1)
#
#data = data.dropna()
    

print(count_na, "\n",col[count_na.index(max(count_na))], max(count_na))
# Out:
# [3, 1608, 1352, 1525, 1465, 1513, 1445, 59, 1615, 1624, 1552, 1516, 3, 1432, 17, 203, 1569, 1461, 1636, 1606, 1490]
#  StructuresEvacuated 1636

# %%
#StructuresEvacuated полностью пустой столбец

# %%
#В датасете имеется много столбцов с метаданными, которые неудобно обрабатывать, которые следует исключить
data = data.drop(['ArchiveYear', 'CanonicalUrl', 'ConditionStatement', 'ControlStatement', 'Extinguished', 'FuelType', 'Location', 'SearchDescription', 'SearchKeywords', 'Started', 'UniqueId', 'Updated', 'StructuresEvacuated'], axis = 1)


#Cтатистический анализ числовых столбцов
data.describe()
# Out:
#          AcresBurned  Active  AirTankers  CalFireIncident  CrewsInvolved  \
# count    1633.000000  1636.0   28.000000           1636.0     171.000000
# mean     4589.443968     1.0    4.071429              1.0      11.561404
# std     27266.337722     0.0    6.399818              0.0      14.455633
# min         0.000000     1.0    0.000000              1.0       0.000000
# 25%        35.000000     1.0    2.000000              1.0       2.500000
# 50%       100.000000     1.0    2.000000              1.0       6.000000
# 75%       422.000000     1.0    4.000000              1.0      13.500000
# max    410203.000000     1.0   27.000000              1.0      82.000000
#
#            Dozers     Engines  Fatalities  Featured   Final  ...    Longitude  \
# count  123.000000  191.000000   21.000000    1636.0  1636.0  ...  1636.000000
# mean     7.585366   23.565445    8.619048       1.0     1.0  ...  -108.082642
# std     14.028616   41.004424   18.529642       0.0     0.0  ...    37.006927
# min      0.000000    0.000000    1.000000       1.0     1.0  ...  -124.196290
# 25%      1.000000    5.000000    1.000000       1.0     1.0  ...  -121.768358
# 50%      2.000000   11.000000    3.000000       1.0     1.0  ...  -120.461560
# 75%      5.000000   24.000000    6.000000       1.0     1.0  ...  -117.474072
# max     76.000000  256.000000   85.000000       1.0     1.0  ...   118.908200
#
#        MajorIncident  PercentContained  PersonnelInvolved  Public  \
# count         1636.0            1633.0         204.000000  1636.0
# mean             1.0             100.0         328.553922     1.0
# std              0.0               0.0         521.138789     0.0
# min              1.0             100.0           0.000000     1.0
# 25%              1.0             100.0          55.000000     1.0
# 50%              1.0             100.0         151.500000     1.0
# 75%              1.0             100.0         350.000000     1.0
# max              1.0             100.0        3100.000000     1.0
#
#             Status  StructuresDamaged  StructuresDestroyed  \
# count  1636.000000          67.000000           175.000000
# mean      0.998778          67.970149           271.788571
# std       0.034953         155.771975          1557.255963
# min       0.000000           0.000000             0.000000
# 25%       1.000000           1.000000             1.000000
# 50%       1.000000           6.000000             7.000000
# 75%       1.000000          49.500000            41.500000
# max       1.000000         783.000000         18804.000000
#
#        StructuresThreatened  WaterTenders
# count             30.000000    146.000000
# mean             522.800000      7.815068
# std              739.586856     12.719251
# min                0.000000      1.000000
# 25%                0.000000      2.000000
# 50%               45.000000      4.000000
# 75%             1043.750000      6.000000
# max             2600.000000     79.000000
#
# [8 rows x 23 columns]

# %%
outs = []

for i in (num_cols+bin_cols):
    if max(data[i]) > 5*data[i].mean():
        outs.append(i)

print(outs, len(outs))
    
#Анамальные отклонения в столбцах приведенных ниже
#['AcresBurned', 'AirTankers', 'CrewsInvolved', 'Dozers', 'Engines', 'Fatalities', 'Helicopters', 'Injuries', 'PersonnelInvolved', 'StructuresDamaged', 'StructuresDestroyed', 'WaterTenders', 'Status']
# Out:
# ['AcresBurned'] 1

# %%
# Нормализация признаков через стандартное отклонение

md = data.mean().mean()
data = data.fillna(md)

scale_features_std = StandardScaler()
features_std = scale_features_std.fit_transform(data[num_cols+bin_cols])

data[num_cols+bin_cols] = features_std

# %%
mean = []
s = 0
for i in range(len(num_cols+bin_cols)):
    for j in range(len(data[col[1]])):
        s += features_std[j][i]
    s = s/1636
    mean.append(s)
    s = 0

print(num_cols[mean.index(max(mean))], max(mean))
# Out:
# Dozers 3.859789423692239e-15

# %%
#Столбцом с максимальным средним значением после нормировки признаков через стандартное отклонение является Dozers

# %%
#Явного столбца, который бы оценивал силу пожара, нет, поэтому буду опираться на площадь выжженных лесов

#Нормализуем данные
#d = preprocessing.normalize(data, axis = 0)
#norm_data = pd.DataFrame(d, columns = data.columns)
#new_data = pd.concat([norm_data, data[bin_cols]], sort = False, axis = 1)

target = data.loc[:, data.columns.isin(['AcresBurned'])]
train = data.drop(['AcresBurned'], axis = 1)

# %%
#Выделяем тренировочную и тестовую выборки 
# y - целевая переменная(target)
X_train, X_test, y_train, y_test = train_test_split(train, target, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
print(N_train, _)
# Out:
# 1145 22

# %%
#1145 объектов попадает в тренировочную выборку при использовании 
#train_test_split с параметрами test_size = 0.3, random_state = 42

# %%
#Корреляция признаков
corr_frame = data.corr()
corr_frame
# Out:
#                       AcresBurned  Active  AirTankers  CalFireIncident  \
# AcresBurned              1.000000     NaN    0.017007              NaN
# Active                        NaN     NaN         NaN              NaN
# AirTankers               0.017007     NaN    1.000000              NaN
# CalFireIncident               NaN     NaN         NaN              NaN
# CrewsInvolved           -0.041623     NaN    0.369694              NaN
# Dozers                  -0.050835     NaN    0.430664              NaN
# Engines                 -0.021455     NaN    0.354444              NaN
# Fatalities              -0.548005     NaN   -0.015002              NaN
# Featured                      NaN     NaN         NaN              NaN
# Final                         NaN     NaN         NaN              NaN
# Helicopters             -0.030117     NaN    0.503937              NaN
# Injuries                -0.236813     NaN    0.086891              NaN
# Latitude                -0.002141     NaN    0.005025              NaN
# Longitude               -0.019410     NaN   -0.004863              NaN
# MajorIncident                 NaN     NaN         NaN              NaN
# PercentContained        -0.006808     NaN    0.005654              NaN
# PersonnelInvolved        0.094433     NaN   -0.078424              NaN
# Public                        NaN     NaN         NaN              NaN
# Status                   0.005602     NaN   -0.004615              NaN
# StructuresDamaged       -0.045526     NaN    0.076574              NaN
# StructuresDestroyed      0.194286     NaN    0.021608              NaN
# StructuresThreatened     0.289701     NaN    0.031457              NaN
# WaterTenders            -0.045291     NaN    0.356883              NaN
#
#                       CrewsInvolved    Dozers   Engines  Fatalities  Featured  \
# AcresBurned               -0.041623 -0.050835 -0.021455   -0.548005       NaN
# Active                          NaN       NaN       NaN         NaN       NaN
# AirTankers                 0.369694  0.430664  0.354444   -0.015002       NaN
# CalFireIncident                 NaN       NaN       NaN         NaN       NaN
# CrewsInvolved              1.000000  0.770973  0.886245    0.047449       NaN
# Dozers                     0.770973  1.000000  0.724644    0.038617       NaN
# Engines                    0.886245  0.724644  1.000000    0.039557       NaN
# Fatalities                 0.047449  0.038617  0.039557    1.000000       NaN
# Featured                        NaN       NaN       NaN         NaN       NaN
# Final                           NaN       NaN       NaN         NaN       NaN
# Helicopters                0.654065  0.713943  0.575216    0.041978       NaN
# Injuries                   0.445897  0.342256  0.443714    0.239468       NaN
# Latitude                   0.006603  0.007738  0.008434   -0.000825       NaN
# Longitude                  0.023184 -0.004655  0.002680    0.041818       NaN
# MajorIncident                   NaN       NaN       NaN         NaN       NaN
# PercentContained           0.014615  0.012200  0.015317    0.004874       NaN
# PersonnelInvolved         -0.173235 -0.260197  0.006836   -0.017760       NaN
# Public                          NaN       NaN       NaN         NaN       NaN
# Status                    -0.011930 -0.009958 -0.012502   -0.003979       NaN
# StructuresDamaged          0.282492  0.239879  0.267746    0.050220       NaN
# StructuresDestroyed       -0.017267 -0.047814 -0.001236   -0.319406       NaN
# StructuresThreatened      -0.005842 -0.020548  0.030308   -0.163899       NaN
# WaterTenders               0.861849  0.789681  0.797309    0.052856       NaN
#
#                       Final  ...  Longitude  MajorIncident  PercentContained  \
# AcresBurned             NaN  ...  -0.019410            NaN         -0.006808
# Active                  NaN  ...        NaN            NaN               NaN
# AirTankers              NaN  ...  -0.004863            NaN          0.005654
# CalFireIncident         NaN  ...        NaN            NaN               NaN
# CrewsInvolved           NaN  ...   0.023184            NaN          0.014615
# Dozers                  NaN  ...  -0.004655            NaN          0.012200
# Engines                 NaN  ...   0.002680            NaN          0.015317
# Fatalities              NaN  ...   0.041818            NaN          0.004874
# Featured                NaN  ...        NaN            NaN               NaN
# Final                   NaN  ...        NaN            NaN               NaN
# Helicopters             NaN  ...   0.021093            NaN          0.009967
# Injuries                NaN  ...  -0.002848            NaN          0.012057
# Latitude                NaN  ...  -0.078975            NaN         -0.000641
# Longitude               NaN  ...   1.000000            NaN         -0.011950
# MajorIncident           NaN  ...        NaN            NaN               NaN
# PercentContained        NaN  ...  -0.011950            NaN          1.000000
# PersonnelInvolved       NaN  ...  -0.002826            NaN         -0.002094
# Public                  NaN  ...        NaN            NaN               NaN
# Status                  NaN  ...   0.008765            NaN         -0.407374
# StructuresDamaged       NaN  ...   0.010222            NaN          0.006784
# StructuresDestroyed     NaN  ...  -0.013750            NaN         -0.000142
# StructuresThreatened    NaN  ...  -0.022544            NaN         -0.002001
# WaterTenders            NaN  ...   0.041168            NaN          0.013398
#
#                       PersonnelInvolved  Public    Status  StructuresDamaged  \
# AcresBurned                    0.094433     NaN  0.005602          -0.045526
# Active                              NaN     NaN       NaN                NaN
# AirTankers                    -0.078424     NaN -0.004615           0.076574
# CalFireIncident                     NaN     NaN       NaN                NaN
# CrewsInvolved                 -0.173235     NaN -0.011930           0.282492
# Dozers                        -0.260197     NaN -0.009958           0.239879
# Engines                        0.006836     NaN -0.012502           0.267746
# Fatalities                    -0.017760     NaN -0.003979           0.050220
# Featured                            NaN     NaN       NaN                NaN
# Final                               NaN     NaN       NaN                NaN
# Helicopters                   -0.416770     NaN -0.008136           0.182626
# Injuries                      -0.143381     NaN -0.009842           0.229717
# Latitude                      -0.001557     NaN  0.000864           0.003523
# Longitude                     -0.002826     NaN  0.008765           0.010222
# MajorIncident                       NaN     NaN       NaN                NaN
# PercentContained              -0.002094     NaN -0.407374           0.006784
# PersonnelInvolved              1.000000     NaN  0.001709          -0.080596
# Public                              NaN     NaN       NaN                NaN
# Status                         0.001709     NaN  1.000000          -0.005537
# StructuresDamaged             -0.080596     NaN -0.005537           1.000000
# StructuresDestroyed            0.080009     NaN  0.000116           0.065814
# StructuresThreatened           0.226440     NaN  0.001633           0.022172
# WaterTenders                  -0.220201     NaN -0.010936           0.248624
#
#                       StructuresDestroyed  StructuresThreatened  WaterTenders
# AcresBurned                      0.194286              0.289701     -0.045291
# Active                                NaN                   NaN           NaN
# AirTankers                       0.021608              0.031457      0.356883
# CalFireIncident                       NaN                   NaN           NaN
# CrewsInvolved                   -0.017267             -0.005842      0.861849
# Dozers                          -0.047814             -0.020548      0.789681
# Engines                         -0.001236              0.030308      0.797309
# Fatalities                      -0.319406             -0.163899      0.052856
# Featured                              NaN                   NaN           NaN
# Final                                 NaN                   NaN           NaN
# Helicopters                     -0.063058             -0.031523      0.665251
# Injuries                        -0.043069             -0.138330      0.393717
# Latitude                         0.001394              0.001247      0.004336
# Longitude                       -0.013750             -0.022544      0.041168
# MajorIncident                         NaN                   NaN           NaN
# PercentContained                -0.000142             -0.002001      0.013398
# PersonnelInvolved                0.080009              0.226440     -0.220201
# Public                                NaN                   NaN           NaN
# Status                           0.000116              0.001633     -0.010936
# StructuresDamaged                0.065814              0.022172      0.248624
# StructuresDestroyed              1.000000              0.000263     -0.028946
# StructuresThreatened             0.000263              1.000000      0.003110
# WaterTenders                    -0.028946              0.003110      1.000000
#
# [23 rows x 23 columns]

# %%
#Используем метод PCA

pca = PCA()
pca.fit(X_train)
X_pca = pca.transform(X_train)

# %%
for i, component in enumerate(pca.components_):
    print("{} component: {}% of initial variance".format(i + 1, 
          round(100 * pca.explained_variance_ratio_[i], 2)))
    print(" + ".join("%.3f x %s" % (value, name)
                     for value, name in zip(component, train.columns)))
# Out:
# 1 component: 63.9% of initial variance
# -0.000 x Active + 0.000 x AirTankers + -0.000 x CalFireIncident + 0.000 x CrewsInvolved + 0.000 x Dozers + 0.000 x Engines + 0.000 x Fatalities + -0.000 x Featured + -0.000 x Final + 0.000 x Helicopters + 0.000 x Injuries + 1.000 x Latitude + -0.016 x Longitude + -0.000 x MajorIncident + -0.000 x PercentContained + -0.000 x PersonnelInvolved + 0.000 x Public + 0.000 x Status + 0.000 x StructuresDamaged + 0.000 x StructuresDestroyed + 0.001 x StructuresThreatened + 0.000 x WaterTenders
# 2 component: 32.63% of initial variance
# 0.000 x Active + 0.000 x AirTankers + -0.000 x CalFireIncident + 0.000 x CrewsInvolved + -0.000 x Dozers + 0.000 x Engines + -0.001 x Fatalities + -0.000 x Featured + -0.000 x Final + -0.000 x Helicopters + -0.001 x Injuries + -0.001 x Latitude + -0.008 x Longitude + -0.000 x MajorIncident + -0.000 x PercentContained + 0.002 x PersonnelInvolved + 0.000 x Public + 0.000 x Status + 0.000 x StructuresDamaged + -0.000 x StructuresDestroyed + 1.000 x StructuresThreatened + 0.000 x WaterTenders
# 3 component: 3.28% of initial variance
# 0.000 x Active + 0.001 x AirTankers + -0.000 x CalFireIncident + 0.001 x CrewsInvolved + 0.000 x Dozers + 0.000 x Engines + 0.001 x Fatalities + 0.000 x Featured + 0.000 x Final + 0.001 x Helicopters + -0.000 x Injuries + 0.016 x Latitude + 1.000 x Longitude + -0.000 x MajorIncident + -0.003 x PercentContained + -0.000 x PersonnelInvolved + -0.000 x Public + 0.000 x Status + 0.000 x StructuresDamaged + -0.000 x StructuresDestroyed + 0.008 x StructuresThreatened + 0.001 x WaterTenders
# 4 component: 0.16% of initial variance
# -0.000 x Active + 0.001 x AirTankers + 0.000 x CalFireIncident + 0.002 x CrewsInvolved + 0.002 x Dozers + 0.002 x Engines + 0.001 x Fatalities + -0.000 x Featured + -0.000 x Final + 0.002 x Helicopters + 0.002 x Injuries + 0.000 x Latitude + 0.003 x Longitude + -0.000 x MajorIncident + 0.998 x PercentContained + -0.000 x PersonnelInvolved + 0.000 x Public + -0.062 x Status + 0.001 x StructuresDamaged + -0.000 x StructuresDestroyed + 0.000 x StructuresThreatened + 0.002 x WaterTenders
# 5 component: 0.01% of initial variance
# 0.000 x Active + -0.278 x AirTankers + 0.000 x CalFireIncident + -0.413 x CrewsInvolved + -0.417 x Dozers + -0.383 x Engines + -0.038 x Fatalities + 0.000 x Featured + 0.000 x Final + -0.376 x Helicopters + -0.232 x Injuries + 0.000 x Latitude + 0.002 x Longitude + -0.000 x MajorIncident + 0.006 x PercentContained + 0.189 x PersonnelInvolved + 0.000 x Public + 0.005 x Status + -0.171 x StructuresDamaged + 0.046 x StructuresDestroyed + -0.001 x StructuresThreatened + -0.410 x WaterTenders
# 6 component: 0.0% of initial variance
# 0.000 x Active + 0.299 x AirTankers + 0.000 x CalFireIncident + 0.044 x CrewsInvolved + 0.026 x Dozers + 0.106 x Engines + -0.435 x Fatalities + 0.000 x Featured + -0.000 x Final + -0.025 x Helicopters + -0.193 x Injuries + -0.000 x Latitude + 0.000 x Longitude + 0.000 x MajorIncident + 0.000 x PercentContained + 0.344 x PersonnelInvolved + 0.000 x Public + 0.000 x Status + 0.070 x StructuresDamaged + 0.739 x StructuresDestroyed + -0.002 x StructuresThreatened + 0.013 x WaterTenders
# 7 component: 0.0% of initial variance
# -0.000 x Active + -0.016 x AirTankers + -0.000 x CalFireIncident + 0.115 x CrewsInvolved + -0.006 x Dozers + 0.273 x Engines + 0.334 x Fatalities + -0.000 x Featured + -0.000 x Final + -0.247 x Helicopters + 0.227 x Injuries + -0.000 x Latitude + -0.000 x Longitude + -0.000 x MajorIncident + -0.003 x PercentContained + 0.808 x PersonnelInvolved + -0.000 x Public + -0.032 x Status + 0.020 x StructuresDamaged + -0.171 x StructuresDestroyed + -0.001 x StructuresThreatened + 0.058 x WaterTenders
# 8 component: 0.0% of initial variance
# 0.000 x Active + -0.043 x AirTankers + -0.000 x CalFireIncident + -0.000 x CrewsInvolved + -0.005 x Dozers + -0.007 x Engines + -0.012 x Fatalities + 0.000 x Featured + 0.000 x Final + -0.008 x Helicopters + 0.020 x Injuries + 0.000 x Latitude + 0.000 x Longitude + 0.000 x MajorIncident + -0.062 x PercentContained + -0.035 x PersonnelInvolved + -0.000 x Public + -0.995 x Status + 0.028 x StructuresDamaged + 0.031 x StructuresDestroyed + 0.000 x StructuresThreatened + -0.000 x WaterTenders
# 9 component: 0.0% of initial variance
# -0.000 x Active + -0.638 x AirTankers + 0.000 x CalFireIncident + 0.085 x CrewsInvolved + -0.033 x Dozers + 0.057 x Engines + -0.040 x Fatalities + -0.000 x Featured + 0.000 x Final + -0.205 x Helicopters + 0.406 x Injuries + -0.000 x Latitude + 0.001 x Longitude + -0.000 x MajorIncident + 0.004 x PercentContained + -0.146 x PersonnelInvolved + -0.000 x Public + 0.066 x Status + 0.476 x StructuresDamaged + 0.342 x StructuresDestroyed + 0.001 x StructuresThreatened + 0.063 x WaterTenders
# 10 component: 0.0% of initial variance
# -0.000 x Active + 0.223 x AirTankers + 0.000 x CalFireIncident + -0.053 x CrewsInvolved + -0.037 x Dozers + -0.095 x Engines + -0.017 x Fatalities + -0.000 x Featured + 0.000 x Final + -0.015 x Helicopters + -0.348 x Injuries + 0.000 x Latitude + -0.000 x Longitude + -0.000 x MajorIncident + 0.000 x PercentContained + 0.070 x PersonnelInvolved + -0.000 x Public + -0.003 x Status + 0.847 x StructuresDamaged + -0.285 x StructuresDestroyed + -0.001 x StructuresThreatened + -0.112 x WaterTenders
# 11 component: 0.0% of initial variance
# -0.000 x Active + 0.330 x AirTankers + -0.000 x CalFireIncident + -0.114 x CrewsInvolved + -0.106 x Dozers + -0.160 x Engines + 0.754 x Fatalities + -0.000 x Featured + 0.000 x Final + 0.073 x Helicopters + 0.137 x Injuries + -0.000 x Latitude + -0.001 x Longitude + -0.000 x MajorIncident + -0.000 x PercentContained + -0.152 x PersonnelInvolved + 0.000 x Public + 0.003 x Status + 0.102 x StructuresDamaged + 0.446 x StructuresDestroyed + 0.002 x StructuresThreatened + -0.127 x WaterTenders
# 12 component: 0.0% of initial variance
# 0.000 x Active + 0.414 x AirTankers + 0.000 x CalFireIncident + -0.160 x CrewsInvolved + -0.177 x Dozers + -0.147 x Engines + -0.354 x Fatalities + -0.000 x Featured + 0.000 x Final + 0.001 x Helicopters + 0.737 x Injuries + -0.000 x Latitude + 0.001 x Longitude + -0.000 x MajorIncident + -0.000 x PercentContained + 0.002 x PersonnelInvolved + 0.000 x Public + 0.000 x Status + 0.071 x StructuresDamaged + -0.151 x StructuresDestroyed + 0.000 x StructuresThreatened + -0.233 x WaterTenders
# 13 component: 0.0% of initial variance
# -0.000 x Active + -0.299 x AirTankers + 0.000 x CalFireIncident + -0.236 x CrewsInvolved + 0.199 x Dozers + -0.241 x Engines + -0.002 x Fatalities + -0.000 x Featured + 0.000 x Final + 0.777 x Helicopters + 0.071 x Injuries + -0.000 x Latitude + -0.000 x Longitude + 0.000 x MajorIncident + 0.000 x PercentContained + 0.348 x PersonnelInvolved + 0.000 x Public + -0.000 x Status + 0.054 x StructuresDamaged + 0.042 x StructuresDestroyed + -0.000 x StructuresThreatened + -0.146 x WaterTenders
# 14 component: 0.0% of initial variance
# -0.000 x Active + 0.048 x AirTankers + 0.000 x CalFireIncident + -0.280 x CrewsInvolved + 0.845 x Dozers + -0.237 x Engines + 0.013 x Fatalities + -0.000 x Featured + -0.000 x Final + -0.375 x Helicopters + 0.055 x Injuries + 0.000 x Latitude + 0.000 x Longitude + -0.000 x MajorIncident + 0.000 x PercentContained + -0.001 x PersonnelInvolved + 0.000 x Public + -0.000 x Status + -0.008 x StructuresDamaged + 0.013 x StructuresDestroyed + 0.000 x StructuresThreatened + -0.071 x WaterTenders
# 15 component: 0.0% of initial variance
# -0.000 x Active + -0.055 x AirTankers + -0.000 x CalFireIncident + 0.219 x CrewsInvolved + 0.158 x Dozers + 0.463 x Engines + 0.019 x Fatalities + 0.000 x Featured + 0.000 x Final + 0.046 x Helicopters + -0.041 x Injuries + -0.000 x Latitude + 0.001 x Longitude + 0.000 x MajorIncident + -0.000 x PercentContained + -0.108 x PersonnelInvolved + -0.000 x Public + 0.000 x Status + -0.028 x StructuresDamaged + 0.006 x StructuresDestroyed + 0.000 x StructuresThreatened + -0.833 x WaterTenders
# 16 component: 0.0% of initial variance
# 0.000 x Active + 0.002 x AirTankers + 0.000 x CalFireIncident + -0.764 x CrewsInvolved + -0.048 x Dozers + 0.616 x Engines + 0.005 x Fatalities + 0.000 x Featured + -0.000 x Final + 0.042 x Helicopters + -0.011 x Injuries + -0.000 x Latitude + 0.000 x Longitude + -0.000 x MajorIncident + -0.000 x PercentContained + -0.098 x PersonnelInvolved + 0.000 x Public + 0.000 x Status + 0.042 x StructuresDamaged + -0.001 x StructuresDestroyed + 0.000 x StructuresThreatened + 0.147 x WaterTenders
# 17 component: 0.0% of initial variance
# -0.000 x Active + 0.000 x AirTankers + 1.000 x CalFireIncident + 0.000 x CrewsInvolved + -0.000 x Dozers + -0.000 x Engines + 0.000 x Fatalities + -0.018 x Featured + -0.019 x Final + -0.000 x Helicopters + 0.000 x Injuries + -0.000 x Latitude + 0.000 x Longitude + 0.012 x MajorIncident + -0.000 x PercentContained + -0.000 x PersonnelInvolved + -0.005 x Public + -0.000 x Status + -0.000 x StructuresDamaged + -0.000 x StructuresDestroyed + 0.000 x StructuresThreatened + -0.000 x WaterTenders
# 18 component: 0.0% of initial variance
# 0.000 x Active + 0.000 x AirTankers + 0.027 x CalFireIncident + -0.000 x CrewsInvolved + 0.000 x Dozers + -0.000 x Engines + 0.000 x Fatalities + 0.720 x Featured + 0.682 x Final + -0.000 x Helicopters + 0.000 x Injuries + -0.000 x Latitude + 0.000 x Longitude + -0.101 x MajorIncident + -0.000 x PercentContained + 0.000 x PersonnelInvolved + -0.078 x Public + -0.000 x Status + -0.000 x StructuresDamaged + -0.000 x StructuresDestroyed + 0.000 x StructuresThreatened + 0.000 x WaterTenders
# 19 component: 0.0% of initial variance
# 0.000 x Active + 0.000 x AirTankers + -0.010 x CalFireIncident + -0.000 x CrewsInvolved + 0.000 x Dozers + -0.000 x Engines + -0.000 x Fatalities + 0.422 x Featured + -0.392 x Final + 0.000 x Helicopters + 0.000 x Injuries + 0.000 x Latitude + -0.000 x Longitude + 0.693 x MajorIncident + 0.000 x PercentContained + 0.000 x PersonnelInvolved + -0.434 x Public + 0.000 x Status + 0.000 x StructuresDamaged + 0.000 x StructuresDestroyed + 0.000 x StructuresThreatened + 0.000 x WaterTenders
# 20 component: 0.0% of initial variance
# 0.000 x Active + -0.000 x AirTankers + -0.006 x CalFireIncident + -0.000 x CrewsInvolved + -0.000 x Dozers + 0.000 x Engines + 0.000 x Fatalities + -0.550 x Featured + 0.595 x Final + -0.000 x Helicopters + -0.000 x Injuries + -0.000 x Latitude + -0.000 x Longitude + 0.410 x MajorIncident + 0.000 x PercentContained + -0.000 x PersonnelInvolved + -0.419 x Public + 0.000 x Status + -0.000 x StructuresDamaged + 0.000 x StructuresDestroyed + 0.000 x StructuresThreatened + 0.000 x WaterTenders
# 21 component: 0.0% of initial variance
# -0.000 x Active + -0.000 x AirTankers + 0.000 x CalFireIncident + 0.000 x CrewsInvolved + 0.000 x Dozers + -0.000 x Engines + 0.000 x Fatalities + -0.011 x Featured + -0.166 x Final + 0.000 x Helicopters + -0.000 x Injuries + -0.000 x Latitude + -0.000 x Longitude + -0.585 x MajorIncident + 0.000 x PercentContained + 0.000 x PersonnelInvolved + -0.794 x Public + 0.000 x Status + -0.000 x StructuresDamaged + -0.000 x StructuresDestroyed + -0.000 x StructuresThreatened + -0.000 x WaterTenders
# 22 component: 0.0% of initial variance
# 1.000 x Active + 0.000 x AirTankers + 0.000 x CalFireIncident + 0.000 x CrewsInvolved + 0.000 x Dozers + 0.000 x Engines + 0.000 x Fatalities + 0.000 x Featured + 0.000 x Final + 0.000 x Helicopters + 0.000 x Injuries + 0.000 x Latitude + 0.000 x Longitude + 0.000 x MajorIncident + 0.000 x PercentContained + 0.000 x PersonnelInvolved + 0.000 x Public + 0.000 x Status + 0.000 x StructuresDamaged + 0.000 x StructuresDestroyed + 0.000 x StructuresThreatened + 0.000 x WaterTenders

# %%
#График зависимости доли объяснённой дисперсии от числа компонент.
plt.figure(figsize=(10,7))
plt.plot(np.cumsum(pca.explained_variance_ratio_), color='k', lw=2)
plt.axhline(0.9, c='r')
plt.axvline(1, c='b')

#90% дисперсии объясняется 2-мя компонентами

# %%
tsne1 = TSNE(learning_rate=200, random_state=13)

transformed1 = tsne1.fit_transform(train)

x_axist1 = transformed1[:, 0]
y_axist1 = transformed1[:, 1]

plt.scatter(x_axist1, y_axist1, c=target['AcresBurned'].tolist())
plt.show()

# %%
tsne1 = TSNE(learning_rate=200, random_state=130)

transformed1 = tsne1.fit_transform(train)

x_axist1 = transformed1[:, 0]
y_axist1 = transformed1[:, 1]

plt.scatter(x_axist1, y_axist1, c=target['AcresBurned'].tolist())
plt.show()

# %%
#Как видно из результатов, данный датасет не поддается кластеризации
